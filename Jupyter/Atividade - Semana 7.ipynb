# %% [markdown]
# Replicar o exemplo dado em sala da previsão de temperatura media da terra e salvar no github o arquivo fonte gerado no jupyter notebook (google colab)
#
# Responder essa atividade com o código no github.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')

# %%
# trasnformando csv em dataframe
dados = pd.read_csv('GlobalTemperatures.csv')

dados.tail(15)
# Out:
#               dt  LandAverageTemperature  LandAverageTemperatureUncertainty  \
# 3177  2014-10-01                  10.330                              0.076
# 3178  2014-11-01                   6.713                              0.121
# 3179  2014-12-01                   4.850                              0.090
# 3180  2015-01-01                   3.881                              0.130
# 3181  2015-02-01                   4.664                              0.121
# 3182  2015-03-01                   6.740                              0.060
# 3183  2015-04-01                   9.313                              0.088
# 3184  2015-05-01                  12.312                              0.081
# 3185  2015-06-01                  14.505                              0.068
# 3186  2015-07-01                  15.051                              0.086
# 3187  2015-08-01                  14.755                              0.072
# ...

# %%
dados = dados.iloc[:,:2]
dados.head()
# Out:
#            dt  LandAverageTemperature
# 0  1750-01-01                   3.034
# 1  1750-02-01                   3.083
# 2  1750-03-01                   5.626
# 3  1750-04-01                   8.490
# 4  1750-05-01                  11.573

# %%
dados.describe()
# Out:
#        LandAverageTemperature
# count             3180.000000
# mean                 8.374731
# std                  4.381310
# min                 -2.080000
# 25%                  4.312000
# 50%                  8.610500
# 75%                 12.548250
# max                 19.021000

# %%
times = pd.DatetimeIndex(dados['dt'])
grouped = dados.groupby([times.year]).mean()

plt.figure(figsize=(15,5))
plt.plot(grouped['LandAverageTemperature'])

plt.title('Temperatura média da terra 1750-2015')
plt.xlabel("Year")
plt.ylabel("Temperatura")
plt.show()

# %%
grouped.head()
# Out:
#       LandAverageTemperature
# dt
# 1750                8.719364
# 1751                7.976143
# 1752                5.779833
# 1753                8.388083
# 1754                8.469333

# %%
dados['LandAverageTemperature'] = dados['LandAverageTemperature'].fillna(method='ffill')

# %%
grouped = dados.groupby([times.year]).mean()
plt.figure(figsize=(14,5))
plt.plot(grouped['LandAverageTemperature'])
plt.show()
